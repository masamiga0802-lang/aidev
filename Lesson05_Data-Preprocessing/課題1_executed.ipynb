# %% [markdown]
# # 課題1：住宅価格のデータの前処理
#
# ここではデータの前処理について理解いただくための課題を用意しました。
#
# ここでは住宅価格のデータセットを利用します。今回の住宅価格のデータは、Colabのランタイムに標準でインストールされている「カリフォルニア州の住宅価格」ではなく、以下のページで配布されている「アイオワ州の住宅価格」のデータを利用します。
#
# このデータは、Dean De Cockという統計学者の論文が出典元とされていて、以下のサイトでCSVファイルの配布と各列の説明がされています。
#
# [Housing prices in Ames, Iowa](https://www.openintro.org/data/index.php?data=ames)
#
# 各セルに入っているコメントの下に、実行するコードを記入してください。また、作業内容の一部にPandasの公式ドキュメントへのリンクを追記していますので、わからない部分がありましたら参照してください。
#
# **注意点：**
#
# - 列名にドット（`.`）が入っているとPandasの処理中にエラーが発生するため、元データの列名から `.` を削除しています
# - PID列のみ、元データから削除しています

# %% [markdown]
# ## 1. 必要なライブラリの読み込み

# %%
# 必要なライブラリの読み込み（変更しないでください）
import sys, importlib
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. データの読み込み
#
# CSVファイル *iowa_ames_housing_price.csv* を読み込み、内容を確認します。

# %%
# データを変数datasetに読み込む
dataset = pd.read_csv('iowa_ames_housing_price.csv')
# 列名に含まれるドットを削除
dataset.columns = [c.replace('.', '') for c in dataset.columns]
# PID または Order 列があれば削除
if 'PID' in dataset.columns:
    dataset = dataset.drop(columns=['PID'])
elif 'Order' in dataset.columns:
    dataset = dataset.drop(columns=['Order'])

# %%
# データの最初の5行を表示
dataset.head()
# Out:
#    area   price  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0  1710  208500          60       RL         65.0     8450   Pave   NaN
# 1  1262  181500          20       RL         80.0     9600   Pave   NaN
# 2  1786  223500          60       RL         68.0    11250   Pave   NaN
# 3  1717  140000          70       RL         60.0     9550   Pave   NaN
# 4  2198  250000          60       RL         84.0    14260   Pave   NaN
#
#   LotShape LandContour  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0      Reg         Lvl  ...           0        0    NaN   NaN         NaN
# 1      Reg         Lvl  ...           0        0    NaN   NaN         NaN
# 2      IR1         Lvl  ...           0        0    NaN   NaN         NaN
# 3      IR1         Lvl  ...           0        0    NaN   NaN         NaN
# 4      IR1         Lvl  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition
# 0       0      2   2008        WD         Normal
# 1       0      5   2007        WD         Normal
# 2       0      9   2008        WD         Normal
# 3       0      2   2006        WD        Abnorml
# 4       0     12   2008        WD         Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# 全データの行数と列数を取得します。DataFrameの`shape` プロパティを参照します。
#
# 参照：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html

# %%
# データの行数、列数を表示
dataset.shape
# Out:
# (1460, 80)

# %% [markdown]
# ## 3. 要約統計量を出力する
#
# データ数、平均や中央値、標準偏差などの統計量を確認することで、データへの理解を深めます。
#
# DataFrameの `describe()` を使うことで、様々な統計量の情報を要約として表示されます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

# %%
# 要約統計量を表示
dataset.describe()
# Out:
#               area          price   MSSubClass  LotFrontage        LotArea  \
# count  1460.000000    1460.000000  1460.000000  1201.000000    1460.000000
# mean   1515.463699  180921.195890    56.897260    70.049958   10516.828082
# std     525.480383   79442.502883    42.300571    24.284752    9981.264932
# min     334.000000   34900.000000    20.000000    21.000000    1300.000000
# 25%    1129.500000  129975.000000    20.000000    59.000000    7553.500000
# 50%    1464.000000  163000.000000    50.000000    69.000000    9478.500000
# 75%    1776.750000  214000.000000    70.000000    80.000000   11601.500000
# max    5642.000000  755000.000000   190.000000   313.000000  215245.000000
#
#        OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea  ...  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1452.000000  ...
# mean      6.099315     5.575342  1971.267808   1984.865753   103.685262  ...
# std       1.382997     1.112799    30.202904     20.645407   181.066207  ...
# min       1.000000     1.000000  1872.000000   1950.000000     0.000000  ...
# 25%       5.000000     5.000000  1954.000000   1967.000000     0.000000  ...
# 50%       6.000000     5.000000  1973.000000   1994.000000     0.000000  ...
# 75%       7.000000     6.000000  2000.000000   2004.000000   166.000000  ...
# max      10.000000     9.000000  2010.000000   2010.000000  1600.000000  ...
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch   X3SsnPorch  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    472.980137    94.244521    46.660274      21.954110     3.409589
# std     213.804841   125.338794    66.256028      61.119149    29.317331
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     334.500000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    25.000000       0.000000     0.000000
# 75%     576.000000   168.000000    68.000000       0.000000     0.000000
# max    1418.000000   857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ## 4. 基本的なデータの操作

# %% [markdown]
# データの抽出・列の分割について学びます。

# %% [markdown]
# ### インデックスを用いた行の指定

# %%
# インデックス番号0から10行分抽出
dataset.iloc[0:10]
# Out:
#    area   price  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0  1710  208500          60       RL         65.0     8450   Pave   NaN
# 1  1262  181500          20       RL         80.0     9600   Pave   NaN
# 2  1786  223500          60       RL         68.0    11250   Pave   NaN
# 3  1717  140000          70       RL         60.0     9550   Pave   NaN
# 4  2198  250000          60       RL         84.0    14260   Pave   NaN
# 5  1362  143000          50       RL         85.0    14115   Pave   NaN
# 6  1694  307000          20       RL         75.0    10084   Pave   NaN
# 7  2090  200000          60       RL          NaN    10382   Pave   NaN
# 8  1774  129900          50       RM         51.0     6120   Pave   NaN
# 9  1077  118000         190       RL         50.0     7420   Pave   NaN
#
#   LotShape LandContour  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0      Reg         Lvl  ...           0        0    NaN    NaN         NaN
# 1      Reg         Lvl  ...           0        0    NaN    NaN         NaN
# 2      IR1         Lvl  ...           0        0    NaN    NaN         NaN
# 3      IR1         Lvl  ...           0        0    NaN    NaN         NaN
# 4      IR1         Lvl  ...           0        0    NaN    NaN         NaN
# 5      IR1         Lvl  ...           0        0    NaN  MnPrv        Shed
# 6      Reg         Lvl  ...           0        0    NaN    NaN         NaN
# 7      IR1         Lvl  ...           0        0    NaN    NaN        Shed
# 8      Reg         Lvl  ...           0        0    NaN    NaN         NaN
# 9      Reg         Lvl  ...           0        0    NaN    NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition
# 0       0      2   2008        WD         Normal
# 1       0      5   2007        WD         Normal
# 2       0      9   2008        WD         Normal
# 3       0      2   2006        WD        Abnorml
# 4       0     12   2008        WD         Normal
# 5     700     10   2009        WD         Normal
# 6       0      8   2007        WD         Normal
# 7     350     11   2009        WD         Normal
# 8       0      4   2008        WD        Abnorml
# 9       0      1   2008        WD         Normal
#
# [10 rows x 80 columns]

# %%
# 最初の10行だけ抽出し、"price"と"LotArea"の列を表示
dataset.loc[:9, ['price', 'LotArea']]
# Out:
#     price  LotArea
# 0  208500     8450
# 1  181500     9600
# 2  223500    11250
# 3  140000     9550
# 4  250000    14260
# 5  143000    14115
# 6  307000    10084
# 7  200000    10382
# 8  129900     6120
# 9  118000     7420

# %% [markdown]
# ### カラム間の演算
#
# PandasのDataFrameでは、列同士の四則演算、ならびに新しい列の追加ができます。
#
# たとえば、`df` というDataFrameの変数があり、中に `a`,`b` というカラムが存在するとき、`df['c'] = df['a'] + df['b']` と記述することで、`a`列と`b`列の加算結果を `c` という新しい列として `df` に追加してくれます。

# %%
# "X1stFlrSF"と"X2ndFlrSF"を合計した"XFlrSF_total"を新たな列としてdatasetに加える
dataset['XFlrSF_total'] = dataset['X1stFlrSF'] + dataset['X2ndFlrSF']

# %%
# datasetからloc関数を使用して"X1stFlrSF"と"X2ndFlrSF","XFlrSF_total"を先頭から5行分表示し、正しく追加されていることを確認する
dataset.loc[:, ['X1stFlrSF', 'X2ndFlrSF', 'XFlrSF_total']].head()
# Out:
#    X1stFlrSF  X2ndFlrSF  XFlrSF_total
# 0        856        854          1710
# 1       1262          0          1262
# 2        920        866          1786
# 3        961        756          1717
# 4       1145       1053          2198

# %% [markdown]
#  ### ダミー変数の作成
#
# 列 `SaleType` は `WD`, `New`, `COD` などで構成されたカテゴリーデータです。 `get_dummies()` 関数を使用してダミー変数に変換しましょう。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html

# %%
# 列'SaleType'をダミー変数に展開したものを変数 dataset に上書きします
if 'SaleType' in dataset.columns:
    dataset = pd.get_dummies(dataset, columns=['SaleType'], prefix='SaleType')
else:
    dataset = dataset

# %%
# ダミー変数が作成されていることを確認します	(datasetの最初の5行だけ出力)
dataset.head()
# Out:
#    area   price  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0  1710  208500          60       RL         65.0     8450   Pave   NaN
# 1  1262  181500          20       RL         80.0     9600   Pave   NaN
# 2  1786  223500          60       RL         68.0    11250   Pave   NaN
# 3  1717  140000          70       RL         60.0     9550   Pave   NaN
# 4  2198  250000          60       RL         84.0    14260   Pave   NaN
#
#   LotShape LandContour  ... XFlrSF_total SaleType_COD SaleType_CWD  \
# 0      Reg         Lvl  ...         1710        False        False
# 1      Reg         Lvl  ...         1262        False        False
# 2      IR1         Lvl  ...         1786        False        False
# 3      IR1         Lvl  ...         1717        False        False
# 4      IR1         Lvl  ...         2198        False        False
#
#   SaleType_Con SaleType_ConLD SaleType_ConLI SaleType_ConLw SaleType_New  \
# 0        False          False          False          False        False
# 1        False          False          False          False        False
# 2        False          False          False          False        False
# 3        False          False          False          False        False
# 4        False          False          False          False        False
#
#    SaleType_Oth  SaleType_WD
# 0         False         True
# 1         False         True
# 2         False         True
# 3         False         True
# 4         False         True
#
# [5 rows x 89 columns]

# %% [markdown]
# ### フィルタリング
#
# DataFrameの `query()` を使いフィルタリングを行ないましょう。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
# 'YearBuilt'が2000以降の物件のみを抽出し、最初の5件のみ表示
dataset.query('YearBuilt >= 2000').head()
# Out:
#     area   price  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0   1710  208500          60       RL         65.0     8450   Pave   NaN
# 2   1786  223500          60       RL         68.0    11250   Pave   NaN
# 4   2198  250000          60       RL         84.0    14260   Pave   NaN
# 6   1694  307000          20       RL         75.0    10084   Pave   NaN
# 11  2324  345000          60       RL         85.0    11924   Pave   NaN
#
#    LotShape LandContour  ... XFlrSF_total SaleType_COD SaleType_CWD  \
# 0       Reg         Lvl  ...         1710        False        False
# 2       IR1         Lvl  ...         1786        False        False
# 4       IR1         Lvl  ...         2198        False        False
# 6       Reg         Lvl  ...         1694        False        False
# 11      IR1         Lvl  ...         2324        False        False
#
#    SaleType_Con SaleType_ConLD SaleType_ConLI SaleType_ConLw SaleType_New  \
# 0         False          False          False          False        False
# 2         False          False          False          False        False
# 4         False          False          False          False        False
# 6         False          False          False          False        False
# 11        False          False          False          False         True
#
#     SaleType_Oth  SaleType_WD
# 0          False         True
# 2          False         True
# 4          False         True
# 6          False         True
# 11         False        False
#
# [5 rows x 89 columns]

# %% [markdown]
# `'LotArea >= 15000 and MSSubClass >= 50'` のように複数の条件を指定できます。

# %%
# 'YearBuilt'が2000以降、'GarageCars'が3以上の物件を抽出し、最初の5件のみ表示
dataset.query('YearBuilt >= 2000 and GarageCars >= 3').head()
# Out:
#     area   price  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 4   2198  250000          60       RL         84.0    14260   Pave   NaN
# 11  2324  345000          60       RL         85.0    11924   Pave   NaN
# 13  1494  279500          20       RL         91.0    10652   Pave   NaN
# 20  2376  325300          60       RL        101.0    14215   Pave   NaN
# 25  1600  256300          20       RL        110.0    14230   Pave   NaN
#
#    LotShape LandContour  ... XFlrSF_total SaleType_COD SaleType_CWD  \
# 4       IR1         Lvl  ...         2198        False        False
# 11      IR1         Lvl  ...         2324        False        False
# 13      IR1         Lvl  ...         1494        False        False
# 20      IR1         Lvl  ...         2376        False        False
# 25      Reg         Lvl  ...         1600        False        False
#
#    SaleType_Con SaleType_ConLD SaleType_ConLI SaleType_ConLw SaleType_New  \
# 4         False          False          False          False        False
# 11        False          False          False          False         True
# 13        False          False          False          False         True
# 20        False          False          False          False         True
# 25        False          False          False          False        False
#
#     SaleType_Oth  SaleType_WD
# 4          False         True
# 11         False        False
# 13         False        False
# 20         False        False
# 25         False         True
#
# [5 rows x 89 columns]

# %% [markdown]
# ## 5. データの可視化

# %% [markdown]
# データを理解するには要約統計量や抽出したデータを確認するだけでは不充分であり、可視化が必要です。

# %% [markdown]
# ### ヒストグラム
#
# 連続変数の分布を確認する際に有効です。DataFrameの `hist()` が使えます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.hist.html

# %%
# datasetの'price'をヒストグラムで表示（DataFrameのhist()を利用する）
import matplotlib.pyplot as plt
dataset['price'].hist(bins=30)
plt.title('price distribution')
plt.xlabel('price')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### 散布図
#
# 2つの変数の関係性を確認する際に有効です。DataFrameの `plot()` が使えます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# %%
# datasetの'LotArea'と'price'を散布図で表示（DataFrameのplot()を利用する）
dataset.plot(kind='scatter', x='LotArea', y='price', alpha=0.6)
plt.title('LotArea vs price')
plt.show()

# %% [markdown]
# ### 棒グラフ
#
# 大小や増減を比較する際に有効です。DataFrameの `plot.bar()` が使えます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html

# %%
#'price'のSaleConditionごとの平均を変数 price_by_condition に格納
price_by_condition = dataset.groupby('SaleCondition')['price'].mean()
price_by_condition
# Out:
# SaleCondition
# Abnorml    146526.623762
# AdjLand    104125.000000
# Alloca     167377.416667
# Family     149600.000000
# Normal     175202.219533
# Partial    272291.752000
# Name: price, dtype: float64

# %%
# price_by_conditionが持つ、棒グラフを表示する命令を実行
price_by_condition.plot.bar()
plt.ylabel('average price')
plt.title('Average price by SaleCondition')
plt.show()

# %% [markdown]
# ### 箱ヒゲ図 (Boxplot)
#
# 複数の変数の分布を比較する際に有効です（棒グラフでは平均の比較はできますが、分布全体の比較はできません)。
#
# DataFrameの `boxplot()` が使えます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.boxplot.html

# %%
# datasetの'SaleCondition'ごとに'price'をDataFrameのboxplotで表示
dataset.boxplot(column='price', by='SaleCondition', rot=90)
plt.title('')
plt.suptitle('')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ## 6. 欠損値の確認
#
# ある列が欠損値を持っているかどうかは Pandas の `isnull()` でわかります。特定の列の欠損値を知りたい場合は `pd.isnull(dataset['LotFrontage'])` のように記述します。また、`.sum()` をつなげることで、その列で欠損値を持つ行数がわかります。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.isnull.html

# %%
# すべての列がそれぞれ、欠損値が何行あるかを取得
dataset.isnull().sum()
# Out:
# area                0
# price               0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
#                  ...
# SaleType_ConLI      0
# SaleType_ConLw      0
# SaleType_New        0
# SaleType_Oth        0
# SaleType_WD         0
# Length: 89, dtype: int64
